# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 
import logging
from ssd.config.defaults import cfg
from ssd.utils.logger import setup_logger
from test import evaluation

# %%
config_file = "configs/rdd_ssd512.yaml"
ckpt = None # The path to the checkpoint for test, default is the latest checkpoint
cfg.merge_from_file(config_file)
cfg.freeze()

logger = setup_logger("SSD", cfg.OUTPUT_DIR)
logger.info("Loaded configuration file {}".format(config_file))
with open(config_file, "r") as cf:
    config_str = "\n" + cf.read()
    logger.info(config_str)
logger.info("Running with config:\n{}".format(cfg))
# Out:
# 2021-04-06 11:10:18,511 SSD INFO: Loaded configuration file configs/rdd_widenet.yaml
# 2021-04-06 11:10:18,511 SSD INFO: Loaded configuration file configs/rdd_widenet.yaml
# 2021-04-06 11:10:18,511 SSD INFO: Loaded configuration file configs/rdd_widenet.yaml
# 2021-04-06 11:10:18,515 SSD INFO:
# MODEL:
#     NUM_CLASSES: 5
#     BACKBONE:
#         NAME: 'resnet_experimental'
#         PRETRAINED: True
#         OUT_CHANNELS: [1024, 512, 512, 256, 256, 256]
#         INPUT_CHANNELS: 3
#     PRIORS:
#         BOXES_PER_LOCATION: [4, 6, 10, 10, 10, 10]
#         MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#         MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#         ASPECT_RATIOS: [[2], [2, 3], [2, 3,4,5], [2, 3, 4, 5], [2,3,4,5], [2,3,4,5]]
#
# INPUT:
#     IMAGE_SIZE: [300, 300]
#     PIXEL_STD: [0.229, 0.224, 0.225]
#     PIXEL_MEAN: [0.485, 0.456, 0.406]
# DATASETS:
#     TRAIN: ("rdd2020_train",)
#     TEST: ("rdd2020_val", )
# SOLVER:
#     MAX_ITER: 50000
#     GAMMA: 0.1
#     BATCH_SIZE: 24
#     MOMENTUM: 0.9
#     LR: 2e-5
# EVAL_STEP: 1000
# MODEL_SAVE_STEP: 1000
# OUTPUT_DIR: 'outputs/wide_resnet-x-600-moreboxes'
# DATASET_DIR: "/work/datasets"
# SOFT_NMS: False
# 2021-04-06 11:10:18,515 SSD INFO:
# MODEL:
#     NUM_CLASSES: 5
#     BACKBONE:
#         NAME: 'resnet_experimental'
#         PRETRAINED: True
#         OUT_CHANNELS: [1024, 512, 512, 256, 256, 256]
#         INPUT_CHANNELS: 3
#     PRIORS:
#         BOXES_PER_LOCATION: [4, 6, 10, 10, 10, 10]
#         MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#         MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#         ASPECT_RATIOS: [[2], [2, 3], [2, 3,4,5], [2, 3, 4, 5], [2,3,4,5], [2,3,4,5]]
#
# INPUT:
#     IMAGE_SIZE: [300, 300]
#     PIXEL_STD: [0.229, 0.224, 0.225]
#     PIXEL_MEAN: [0.485, 0.456, 0.406]
# DATASETS:
#     TRAIN: ("rdd2020_train",)
#     TEST: ("rdd2020_val", )
# SOLVER:
#     MAX_ITER: 50000
#     GAMMA: 0.1
#     BATCH_SIZE: 24
#     MOMENTUM: 0.9
#     LR: 2e-5
# EVAL_STEP: 1000
# MODEL_SAVE_STEP: 1000
# OUTPUT_DIR: 'outputs/wide_resnet-x-600-moreboxes'
# DATASET_DIR: "/work/datasets"
# SOFT_NMS: False
# 2021-04-06 11:10:18,515 SSD INFO:
# MODEL:
#     NUM_CLASSES: 5
#     BACKBONE:
#         NAME: 'resnet_experimental'
#         PRETRAINED: True
#         OUT_CHANNELS: [1024, 512, 512, 256, 256, 256]
#         INPUT_CHANNELS: 3
#     PRIORS:
#         BOXES_PER_LOCATION: [4, 6, 10, 10, 10, 10]
#         MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#         MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#         ASPECT_RATIOS: [[2], [2, 3], [2, 3,4,5], [2, 3, 4, 5], [2,3,4,5], [2,3,4,5]]
#
# INPUT:
#     IMAGE_SIZE: [300, 300]
#     PIXEL_STD: [0.229, 0.224, 0.225]
#     PIXEL_MEAN: [0.485, 0.456, 0.406]
# DATASETS:
#     TRAIN: ("rdd2020_train",)
#     TEST: ("rdd2020_val", )
# SOLVER:
#     MAX_ITER: 50000
#     GAMMA: 0.1
#     BATCH_SIZE: 24
#     MOMENTUM: 0.9
#     LR: 2e-5
# EVAL_STEP: 1000
# MODEL_SAVE_STEP: 1000
# OUTPUT_DIR: 'outputs/wide_resnet-x-600-moreboxes'
# DATASET_DIR: "/work/datasets"
# SOFT_NMS: False
# 2021-04-06 11:10:18,518 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('rdd2020_val',)
#   TRAIN: ('rdd2020_train',)
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 1000
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [0.485, 0.456, 0.406]
#   PIXEL_STD: [0.229, 0.224, 0.225]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: resnet_experimental
#     OUT_CHANNELS: (1024, 512, 512, 256, 256, 256)
#     PRETRAINED: True
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 5
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3, 4, 5], [2, 3, 4, 5], [2, 3, 4, 5], [2, 3, 4, 5]]
#     BOXES_PER_LOCATION: [4, 6, 10, 10, 10, 10]
#     CLIP: True
#     FEATURE_MAPS: [[75, 75], [75, 75], [38, 38], [19, 19], [10, 10]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 1000
# OUTPUT_DIR: outputs/wide_resnet-x-600-moreboxes
# SOFT_NMS: False
# SOLVER:
#   BATCH_SIZE: 24
#   GAMMA: 0.1
#   LR: 2e-05
#   MAX_ITER: 50000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-04-06 11:10:18,518 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('rdd2020_val',)
#   TRAIN: ('rdd2020_train',)
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 1000
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [0.485, 0.456, 0.406]
#   PIXEL_STD: [0.229, 0.224, 0.225]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: resnet_experimental
#     OUT_CHANNELS: (1024, 512, 512, 256, 256, 256)
#     PRETRAINED: True
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 5
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3, 4, 5], [2, 3, 4, 5], [2, 3, 4, 5], [2, 3, 4, 5]]
#     BOXES_PER_LOCATION: [4, 6, 10, 10, 10, 10]
#     CLIP: True
#     FEATURE_MAPS: [[75, 75], [75, 75], [38, 38], [19, 19], [10, 10]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 1000
# OUTPUT_DIR: outputs/wide_resnet-x-600-moreboxes
# SOFT_NMS: False
# SOLVER:
#   BATCH_SIZE: 24
#   GAMMA: 0.1
#   LR: 2e-05
#   MAX_ITER: 50000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-04-06 11:10:18,518 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('rdd2020_val',)
#   TRAIN: ('rdd2020_train',)
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 1000
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [0.485, 0.456, 0.406]
#   PIXEL_STD: [0.229, 0.224, 0.225]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: resnet_experimental
#     OUT_CHANNELS: (1024, 512, 512, 256, 256, 256)
#     PRETRAINED: True
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 5
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3, 4, 5], [2, 3, 4, 5], [2, 3, 4, 5], [2, 3, 4, 5]]
#     BOXES_PER_LOCATION: [4, 6, 10, 10, 10, 10]
#     CLIP: True
#     FEATURE_MAPS: [[75, 75], [75, 75], [38, 38], [19, 19], [10, 10]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 1000
# OUTPUT_DIR: outputs/wide_resnet-x-600-moreboxes
# SOFT_NMS: False
# SOLVER:
#   BATCH_SIZE: 24
#   GAMMA: 0.1
#   LR: 2e-05
#   MAX_ITER: 50000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45

# %%
evaluation(cfg, ckpt=ckpt)
# Out:
# Detector initialized. Total Number of params:  30.26M
# Backbone number of parameters: 28.64M
# SSD Head number of parameters: 1.62M
# 2021-04-06 11:10:21,163 SSD.inference INFO: Loading checkpoint from outputs/wide_resnet-x-600-moreboxes/model_031000.pth
# 2021-04-06 11:10:21,163 SSD.inference INFO: Loading checkpoint from outputs/wide_resnet-x-600-moreboxes/model_031000.pth
# 2021-04-06 11:10:21,163 SSD.inference INFO: Loading checkpoint from outputs/wide_resnet-x-600-moreboxes/model_031000.pth
# Dataset loaded. Subset: val, number of images: 3659
# 2021-04-06 11:10:21,385 SSD.inference INFO: Evaluating rdd2020_val dataset(3659 images):
# 2021-04-06 11:10:21,385 SSD.inference INFO: Evaluating rdd2020_val dataset(3659 images):
# 2021-04-06 11:10:21,385 SSD.inference INFO: Evaluating rdd2020_val dataset(3659 images):
#   0%|          | 0/366 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-c7b6f2a5ff9a> in <module>
# ----> 1 evaluation(cfg, ckpt=ckpt)
#
# ~/home/road-damage-detection/SSD/test.py in evaluation(cfg, ckpt)
#      16     model = torch_utils.to_cuda(model)
#      17     checkpointer.load(ckpt, use_latest=ckpt is None)
# ---> 18     do_evaluation(cfg, model)
#      19
#      20
#
# /opt/conda/lib/python3.8/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.__class__():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~/home/road-damage-detection/SSD/ssd/engine/inference.py in do_evaluation(cfg, model, **kwargs)
#      50         output_folder = pathlib.Path(cfg.OUTPUT_DIR, "inference", dataset_name)
#      51         output_folder.mkdir(exist_ok=True, parents=True)
# ---> 52         eval_result = inference(
#      53             model, data_loader, dataset_name, output_folder, **kwargs)
#      54         eval_results.append(eval_result)
#
# ~/home/road-damage-detection/SSD/ssd/engine/inference.py in inference(model, data_loader, dataset_name, output_folder, **kwargs)
#      37     logger.info(
#      38         "Evaluating {} dataset({} images):".format(dataset_name, len(dataset)))
# ---> 39     predictions = compute_on_dataset(model, data_loader)
#      40     predictions = convert_predictions(predictions)
#      41     return evaluate(dataset=dataset, predictions=predictions, output_dir=output_folder, **kwargs)
#
# /opt/conda/lib/python3.8/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.__class__():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~/home/road-damage-detection/SSD/ssd/engine/inference.py in compute_on_dataset(model, data_loader)
#      23         images, targets, image_ids = batch
#      24         images = torch_utils.to_cuda(images)
# ---> 25         outputs = model(images)
#      26
#      27         outputs = [o.cpu() for o in outputs]
#
# /opt/conda/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     879             result = self._slow_forward(*input, **kwargs)
#     880         else:
# --> 881             result = self.forward(*input, **kwargs)
#     882         for hook in itertools.chain(
#     883                 _global_forward_hooks.values(),
#
# ~/home/road-damage-detection/SSD/ssd/modeling/detector.py in forward(self, images, targets)
#      27     def forward(self, images, targets=None):
#      28         features = self.backbone(images)
# ---> 29         detections, detector_losses = self.box_head(features, targets)
#      30         if self.training:
#      31             return detector_losses
#
# /opt/conda/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     879             result = self._slow_forward(*input, **kwargs)
#     880         else:
# --> 881             result = self.forward(*input, **kwargs)
#     882         for hook in itertools.chain(
#     883                 _global_forward_hooks.values(),
#
# ~/home/road-damage-detection/SSD/ssd/modeling/box_head/box_head.py in forward(self, features, targets)
#      23             return self._forward_train(cls_logits, bbox_pred, targets)
#      24         else:
# ---> 25             return self._forward_test(cls_logits, bbox_pred)
#      26
#      27     def _forward_train(self, cls_logits, bbox_pred, targets):
#
# ~/home/road-damage-detection/SSD/ssd/modeling/box_head/box_head.py in _forward_test(self, cls_logits, bbox_pred)
#      38             self.priors = PriorBox(self.cfg)().to(bbox_pred.device)
#      39         scores = F.softmax(cls_logits, dim=2)
# ---> 40         boxes = box_utils.convert_locations_to_boxes(
#      41             bbox_pred,
#      42             self.priors,
#
# ~/home/road-damage-detection/SSD/ssd/utils/box_utils.py in convert_locations_to_boxes(locations, priors, center_variance, size_variance)
#      24         priors = priors.unsqueeze(0)
#      25     return torch.cat([
# ---> 26         locations[..., :2] * center_variance * priors[..., 2:] + priors[..., :2],
#      27         torch.exp(locations[..., 2:] * size_variance) * priors[..., 2:]
#      28     ], dim=locations.dim() - 1)
#
# RuntimeError: The size of tensor a (9292) must match the size of tensor b (75300) at non-singleton dimension 1
