# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 
import pathlib
import matplotlib.pyplot as plt
from ssd.config.defaults import cfg
from demo import run_demo

# %%
config_file = "configs/rdd_2020_server-resnet-experimental.yaml"
ckpt = None # The path to the checkpoint for test, default is the latest checkpoint
score_threshold = 0.7
images_dir = "demo/rdd" # chage to "demo/mnist" for MNIST
dataset_type = "rdd2020" # change to "mnist" for MNIST.

cfg.merge_from_file(config_file)
cfg.freeze()

print("Loaded configuration file {}".format(config_file))
with open(config_file, "r") as cf:
    config_str = "\n" + cf.read()
print("Running with config:\n{}".format(cfg))

drawn_images = run_demo(
    cfg=cfg,ckpt=ckpt,
    score_threshold=score_threshold,
    images_dir=pathlib.Path(images_dir),
    output_dir=pathlib.Path(images_dir, "result"),
    dataset_type=dataset_type)
# Out:
# Loaded configuration file configs/rdd_2020_server-resnet-experimental.yaml
# Running with config:
# DATASETS:
#   TEST: ('rdd2020_val',)
#   TRAIN: ('rdd2020_train',)
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 2000
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [0.485, 0.456, 0.406]
#   PIXEL_STD: [0.229, 0.224, 0.225]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: resnet_experimental
#     OUT_CHANNELS: (1024, 512, 512, 256, 256, 256)
#     PRETRAINED: True
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 5
#   PRIORS:
#     ASPECT_RATIOS: [[2, 3], [2, 5], [3, 5], [2, 4], [2, 3], [2, 4]]
#     BOXES_PER_LOCATION: [6, 6, 6, 6, 6, 6]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[45, 45], [99, 99], [153, 153], [207, 207], [261, 261], [315, 315]]
#     MIN_SIZES: [[21, 21], [45, 45], [99, 99], [153, 153], [207, 207], [261, 261]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 1000
# OUTPUT_DIR: outputs/rdd_2020_experimental-custom
# SOLVER:
#   BATCH_SIZE: 22
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 30000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# Predicting on images:   0%|          | 0/49 [00:00<?, ?it/s]
# Detector initialized. Total Number of params:  35.68M
# Backbone number of parameters: 34.31M
# SSD Head number of parameters: 1.37M
# Loaded weights from
# Predicting on images:   2%|▏         | 1/49 [00:00<00:24,  1.96it/s]
# demo/rdd/result/Japan_001205.png
# Predicting on images:   4%|▍         | 2/49 [00:01<00:28,  1.67it/s]
# demo/rdd/result/Japan_001273.png
# Predicting on images:   6%|▌         | 3/49 [00:01<00:25,  1.81it/s]
# demo/rdd/result/Japan_001215.png
# Predicting on images:   8%|▊         | 4/49 [00:02<00:23,  1.92it/s]
# demo/rdd/result/Japan_001230.png
# Predicting on images:  10%|█         | 5/49 [00:02<00:21,  2.04it/s]
# demo/rdd/result/Japan_001249.png
# Predicting on images:  12%|█▏        | 6/49 [00:03<00:20,  2.13it/s]
# demo/rdd/result/Japan_001281.png
# Predicting on images:  14%|█▍        | 7/49 [00:03<00:19,  2.11it/s]
# demo/rdd/result/India_000127.png
# Predicting on images:  16%|█▋        | 8/49 [00:03<00:19,  2.12it/s]
# demo/rdd/result/Japan_001278.png
# Predicting on images:  18%|█▊        | 9/49 [00:04<00:18,  2.19it/s]
# demo/rdd/result/Japan_001252.png
# Predicting on images:  20%|██        | 10/49 [00:04<00:17,  2.23it/s]
# demo/rdd/result/Japan_001238.png
# Predicting on images:  22%|██▏       | 11/49 [00:05<00:16,  2.25it/s]
# demo/rdd/result/Japan_001207.png
# Predicting on images:  24%|██▍       | 12/49 [00:05<00:16,  2.26it/s]
# demo/rdd/result/Japan_001202.png
# Predicting on images:  27%|██▋       | 13/49 [00:06<00:15,  2.25it/s]
# demo/rdd/result/Japan_001269.png
# Predicting on images:  29%|██▊       | 14/49 [00:06<00:15,  2.28it/s]
# demo/rdd/result/Japan_001274.png
# Predicting on images:  31%|███       | 15/49 [00:07<00:17,  1.89it/s]
# demo/rdd/result/Japan_001262.png
# Predicting on images:  33%|███▎      | 16/49 [00:07<00:16,  1.99it/s]
# demo/rdd/result/Japan_001284.png
# Predicting on images:  35%|███▍      | 17/49 [00:08<00:15,  2.08it/s]
# demo/rdd/result/Japan_001296.png
# Predicting on images:  37%|███▋      | 18/49 [00:08<00:14,  2.15it/s]
# demo/rdd/result/Japan_001204.png
# Predicting on images:  39%|███▉      | 19/49 [00:09<00:13,  2.24it/s]
# demo/rdd/result/Japan_001295.png
# Predicting on images:  41%|████      | 20/49 [00:09<00:12,  2.31it/s]
# demo/rdd/result/Japan_001266.png
# Predicting on images:  43%|████▎     | 21/49 [00:09<00:11,  2.38it/s]
# demo/rdd/result/Japan_001208.png
# Predicting on images:  45%|████▍     | 22/49 [00:10<00:11,  2.38it/s]
# demo/rdd/result/Japan_001293.png
# Predicting on images:  47%|████▋     | 23/49 [00:10<00:10,  2.40it/s]
# demo/rdd/result/Japan_001288.png
# Predicting on images:  49%|████▉     | 24/49 [00:11<00:10,  2.40it/s]
# demo/rdd/result/Japan_001216.png
# Predicting on images:  51%|█████     | 25/49 [00:11<00:09,  2.43it/s]
# demo/rdd/result/Japan_001241.png
# Predicting on images:  53%|█████▎    | 26/49 [00:11<00:09,  2.43it/s]
# demo/rdd/result/Japan_001299.png
# Predicting on images:  55%|█████▌    | 27/49 [00:12<00:09,  2.44it/s]
# demo/rdd/result/Japan_001239.png
# Predicting on images:  57%|█████▋    | 28/49 [00:12<00:08,  2.44it/s]
# demo/rdd/result/Japan_001231.png
# Predicting on images:  59%|█████▉    | 29/49 [00:13<00:08,  2.44it/s]
# demo/rdd/result/Japan_001287.png
# Predicting on images:  61%|██████    | 30/49 [00:13<00:07,  2.46it/s]
# demo/rdd/result/Japan_001200.png
# Predicting on images:  63%|██████▎   | 31/49 [00:13<00:07,  2.47it/s]
# demo/rdd/result/Japan_001219.png
# Predicting on images:  65%|██████▌   | 32/49 [00:14<00:06,  2.50it/s]
# demo/rdd/result/Japan_001247.png
# Predicting on images:  67%|██████▋   | 33/49 [00:14<00:06,  2.47it/s]
# demo/rdd/result/Japan_001492.png
# Predicting on images:  69%|██████▉   | 34/49 [00:15<00:06,  2.47it/s]
# demo/rdd/result/Japan_001254.png
# Predicting on images:  71%|███████▏  | 35/49 [00:15<00:05,  2.47it/s]
# demo/rdd/result/Japan_001245.png
# Predicting on images:  73%|███████▎  | 36/49 [00:15<00:05,  2.45it/s]
# demo/rdd/result/Japan_001259.png
# Predicting on images:  76%|███████▌  | 37/49 [00:16<00:04,  2.50it/s]
# demo/rdd/result/Japan_001233.png
# Predicting on images:  78%|███████▊  | 38/49 [00:16<00:04,  2.50it/s]
# demo/rdd/result/Japan_001228.png
# Predicting on images:  80%|███████▉  | 39/49 [00:17<00:04,  2.49it/s]
# demo/rdd/result/Japan_001264.png
# Predicting on images:  82%|████████▏ | 40/49 [00:17<00:03,  2.50it/s]
# demo/rdd/result/Japan_001214.png
# Predicting on images:  84%|████████▎ | 41/49 [00:17<00:03,  2.51it/s]
# demo/rdd/result/Japan_001246.png
# Predicting on images:  86%|████████▌ | 42/49 [00:18<00:02,  2.49it/s]
# demo/rdd/result/Japan_001257.png
# Predicting on images:  88%|████████▊ | 43/49 [00:18<00:02,  2.45it/s]
# demo/rdd/result/Japan_001251.png
# Predicting on images:  90%|████████▉ | 44/49 [00:19<00:02,  2.44it/s]
# demo/rdd/result/Japan_001265.png
# Predicting on images:  92%|█████████▏| 45/49 [00:19<00:01,  2.46it/s]
# demo/rdd/result/Japan_001298.png
# Predicting on images:  94%|█████████▍| 46/49 [00:19<00:01,  2.48it/s]
# demo/rdd/result/Japan_001221.png
# Predicting on images:  96%|█████████▌| 47/49 [00:20<00:00,  2.49it/s]
# demo/rdd/result/Japan_001243.png
# Predicting on images:  98%|█████████▊| 48/49 [00:20<00:00,  2.50it/s]
# demo/rdd/result/Japan_001242.png
# Predicting on images: 100%|██████████| 49/49 [00:21<00:00,  2.32it/s]
# demo/rdd/result/Japan_001236.png

# %%
# Example to plot the first drawn image
print("Number of images:", len(drawn_images))
plt.imshow(drawn_images[0])
# Out:
# Number of images: 49

# %%
plt.imshow(drawn_images[1])
